# %%
import numpy as np
import tensorflow as tf
import spacetrack.operators as op
from datetime import datetime,timedelta
import pandas as pd
from spacetrack import SpaceTrackClient
from io import StringIO  # Import StringIO
import time
import matplotlib.pyplot as plt
import tqdm
# Out:
# 2025-08-11 16:01:58.994537: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-11 16:01:59.089149: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-11 16:01:59.165842: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754902919.265573    5553 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754902919.295245    5553 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-11 16:01:59.514399: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
def circular_difference(angle1, angle2, period=360.0):
    """
    Compute circular difference between two angles
    
    Parameters:
    angle1, angle2: angles in degrees [0, 360]
    period: period of the circular data (default 360 degrees)
    
    Returns:
    difference: shortest angular difference in [-180, 180]
    """
    diff = angle2 - angle1
    
    # Wrap to [-180, 180] range
    diff = ((diff + 180) % period) - 180
    
    return diff

# %% [markdown]
# # Multi-output models
# - Vector Autoregression
# - RNN (TF)
# - MultiOutput Regressor

# %%
resample_tle_df = pd.read_csv('resample_df_allFeatures.csv')
resample_tle_df.set_index('Epoch', inplace=True)
resample_tle_df.head()
# Out:
#             First Derivative Mean Motion  Inclination (degrees)  \
# Epoch
# 2022-12-31                      0.000157              51.644800
# 2023-01-01                      0.000166              51.644567
# 2023-01-02                      0.000175              51.644680
# 2023-01-03                      0.000162              51.644860
# 2023-01-04                      0.000142              51.644740
#
#             Right Ascension of the Ascending Node (degrees)  \
# Epoch
# 2022-12-31                                        77.042350
# 2023-01-01                                        74.151133
# 2023-01-02                                        69.554840
# 2023-01-03                                        64.713420
# 2023-01-04                                        59.072260
#
#             Argument of Perigee (degrees)  Mean Anomaly (degrees)  \
# Epoch
# 2022-12-31                     208.400550              320.463100
# 2023-01-01                     211.103567              277.293067
# 2023-01-02                     215.693640              221.644740
# 2023-01-03                     219.864140              202.583880
# 2023-01-04                     225.670000              219.529780
#
#             Eccentricity  Mean Motion (revolutions per day)  \
# Epoch
# 2022-12-31      0.000525                          15.497978
# 2023-01-01      0.000519                          15.498221
# 2023-01-02      0.000511                          15.498584
# 2023-01-03      0.000499                          15.498874
# 2023-01-04      0.000497                          15.499123
#
#             Revolution Number at Epoch
# Epoch
# 2022-12-31                37584.500000
# 2023-01-01                37593.666667
# 2023-01-02                37608.000000
# 2023-01-03                37623.200000
# 2023-01-04                37640.800000

# %%
resample_tle_df.columns
# Out:
# Index(['First Derivative Mean Motion', 'Inclination (degrees)',
#        'Right Ascension of the Ascending Node (degrees)',
#        'Argument of Perigee (degrees)', 'Mean Anomaly (degrees)',
#        'Eccentricity', 'Mean Motion (revolutions per day)',
#        'Revolution Number at Epoch'],
#       dtype='object')

# %%
# --- 1. Prepare Sample Data ---
data_for_training = resample_tle_df.copy()

# Add_diff
# data_for_training['diff_eccentricity'] = data_for_training['Eccentricity'].diff()
data_for_training['diff_revs_number'] =  data_for_training['Revolution Number at Epoch'].diff()
data_for_training.head()
# Out:
#             First Derivative Mean Motion  Inclination (degrees)  \
# Epoch
# 2022-12-31                      0.000157              51.644800
# 2023-01-01                      0.000166              51.644567
# 2023-01-02                      0.000175              51.644680
# 2023-01-03                      0.000162              51.644860
# 2023-01-04                      0.000142              51.644740
#
#             Right Ascension of the Ascending Node (degrees)  \
# Epoch
# 2022-12-31                                        77.042350
# 2023-01-01                                        74.151133
# 2023-01-02                                        69.554840
# 2023-01-03                                        64.713420
# 2023-01-04                                        59.072260
#
#             Argument of Perigee (degrees)  Mean Anomaly (degrees)  \
# Epoch
# 2022-12-31                     208.400550              320.463100
# 2023-01-01                     211.103567              277.293067
# 2023-01-02                     215.693640              221.644740
# 2023-01-03                     219.864140              202.583880
# 2023-01-04                     225.670000              219.529780
#
#             Eccentricity  Mean Motion (revolutions per day)  \
# Epoch
# 2022-12-31      0.000525                          15.497978
# 2023-01-01      0.000519                          15.498221
# 2023-01-02      0.000511                          15.498584
# 2023-01-03      0.000499                          15.498874
# 2023-01-04      0.000497                          15.499123
#
#             Revolution Number at Epoch  diff_revs_number
# Epoch
# 2022-12-31                37584.500000               NaN
# 2023-01-01                37593.666667          9.166667
# 2023-01-02                37608.000000         14.333333
# 2023-01-03                37623.200000         15.200000
# 2023-01-04                37640.800000         17.600000

# %%
raan_diff = [np.nan]
arg_peri_diff = [np.nan]
mean_anomaly_diff = [np.nan]
inclination_diff = [np.nan]


raan_series = data_for_training['Right Ascension of the Ascending Node (degrees)']
arg_peri_series = data_for_training['Argument of Perigee (degrees)']
mean_anomaly_series = data_for_training['Mean Anomaly (degrees)']
inclination_series = data_for_training['Inclination (degrees)']


for i in range(1, data_for_training.shape[0]):
    
    raan_diff.append(circular_difference(raan_series.iloc[i-1], raan_series.iloc[i]))
    arg_peri_diff.append(circular_difference(arg_peri_series.iloc[i-1], arg_peri_series.iloc[i]))
    mean_anomaly_diff.append(circular_difference(mean_anomaly_series.iloc[i-1], mean_anomaly_series.iloc[i]))
    inclination_diff.append(circular_difference(inclination_series.iloc[i-1], inclination_series.iloc[i]))
    
    
# test_df = TLE_df_time_series.copy()
data_for_training['cirdiff_RA'] = raan_diff
data_for_training['cirdiff_AP'] = arg_peri_diff
data_for_training['cirdiff_MA'] = mean_anomaly_diff
data_for_training['cirdiff_INC'] = inclination_diff

# %%
data_for_training.head()
# Out:
#             First Derivative Mean Motion  Inclination (degrees)  \
# Epoch
# 2022-12-31                      0.000157              51.644800
# 2023-01-01                      0.000166              51.644567
# 2023-01-02                      0.000175              51.644680
# 2023-01-03                      0.000162              51.644860
# 2023-01-04                      0.000142              51.644740
#
#             Right Ascension of the Ascending Node (degrees)  \
# Epoch
# 2022-12-31                                        77.042350
# 2023-01-01                                        74.151133
# 2023-01-02                                        69.554840
# 2023-01-03                                        64.713420
# 2023-01-04                                        59.072260
#
#             Argument of Perigee (degrees)  Mean Anomaly (degrees)  \
# Epoch
# 2022-12-31                     208.400550              320.463100
# 2023-01-01                     211.103567              277.293067
# 2023-01-02                     215.693640              221.644740
# 2023-01-03                     219.864140              202.583880
# 2023-01-04                     225.670000              219.529780
#
#             Eccentricity  Mean Motion (revolutions per day)  \
# Epoch
# 2022-12-31      0.000525                          15.497978
# 2023-01-01      0.000519                          15.498221
# 2023-01-02      0.000511                          15.498584
# 2023-01-03      0.000499                          15.498874
# 2023-01-04      0.000497                          15.499123
#
#             Revolution Number at Epoch  diff_revs_number  cirdiff_RA  \
# Epoch
# 2022-12-31                37584.500000               NaN         NaN
# 2023-01-01                37593.666667          9.166667   -2.891217
# 2023-01-02                37608.000000         14.333333   -4.596293
# 2023-01-03                37623.200000         15.200000   -4.841420
# 2023-01-04                37640.800000         17.600000   -5.641160
#
#             cirdiff_AP  cirdiff_MA  cirdiff_INC
# Epoch
# 2022-12-31         NaN         NaN          NaN
# 2023-01-01    2.703017  -43.170033    -0.000233
# 2023-01-02    4.590073  -55.648327     0.000113
# 2023-01-03    4.170500  -19.060860     0.000180
# 2023-01-04    5.805860   16.945900    -0.000120

# %%
initial_row = data_for_training.iloc[0,:]
data_for_training.dropna(inplace=True)
initial_row
# Out:
# First Derivative Mean Motion                           0.000157
# Inclination (degrees)                                 51.644800
# Right Ascension of the Ascending Node (degrees)       77.042350
# Argument of Perigee (degrees)                        208.400550
# Mean Anomaly (degrees)                               320.463100
# Eccentricity                                           0.000525
# Mean Motion (revolutions per day)                     15.497978
# Revolution Number at Epoch                         37584.500000
# diff_revs_number                                            NaN
# cirdiff_RA                                                  NaN
# cirdiff_AP                                                  NaN
# cirdiff_MA                                                  NaN
# cirdiff_INC                                                 NaN
# Name: 2022-12-31, dtype: float64

# %%
data_for_training.columns
# Out:
# Index(['First Derivative Mean Motion', 'Inclination (degrees)',
#        'Right Ascension of the Ascending Node (degrees)',
#        'Argument of Perigee (degrees)', 'Mean Anomaly (degrees)',
#        'Eccentricity', 'Mean Motion (revolutions per day)',
#        'Revolution Number at Epoch', 'diff_revs_number', 'cirdiff_RA',
#        'cirdiff_AP', 'cirdiff_MA', 'cirdiff_INC'],
#       dtype='object')

# %%
# data_for_training['First Derivative Mean Motion']

# %%
cols_for_training = ['First Derivative Mean Motion', 
       'Mean Motion (revolutions per day)', 
       'Eccentricity',  'diff_revs_number', 'Inclination (degrees)',
       'Right Ascension of the Ascending Node (degrees)',
       'Argument of Perigee (degrees)', 'Mean Anomaly (degrees)']

# Avoid near zero values 
# data_for_training['First Derivative Mean Motion'] = data_for_training['First Derivative Mean Motion']*10000
# data_for_training['Eccentricity'] = data_for_training['Eccentricity']*10000



data = data_for_training[cols_for_training].copy()
data.head()
# Out:
#             First Derivative Mean Motion  Mean Motion (revolutions per day)  \
# Epoch
# 2023-01-01                      0.000166                          15.498221
# 2023-01-02                      0.000175                          15.498584
# 2023-01-03                      0.000162                          15.498874
# 2023-01-04                      0.000142                          15.499123
# 2023-01-05                      0.000139                          15.499368
#
#             Eccentricity  diff_revs_number  Inclination (degrees)  \
# Epoch
# 2023-01-01      0.000519          9.166667              51.644567
# 2023-01-02      0.000511         14.333333              51.644680
# 2023-01-03      0.000499         15.200000              51.644860
# 2023-01-04      0.000497         17.600000              51.644740
# 2023-01-05      0.000490         13.800000              51.644820
#
#             Right Ascension of the Ascending Node (degrees)  \
# Epoch
# 2023-01-01                                        74.151133
# 2023-01-02                                        69.554840
# 2023-01-03                                        64.713420
# 2023-01-04                                        59.072260
# 2023-01-05                                        54.697760
#
#             Argument of Perigee (degrees)  Mean Anomaly (degrees)
# Epoch
# 2023-01-01                     211.103567              277.293067
# 2023-01-02                     215.693640              221.644740
# 2023-01-03                     219.864140              202.583880
# 2023-01-04                     225.670000              219.529780
# 2023-01-05                     228.970120              250.770840

# %%
data.describe()
# Out:
#        First Derivative Mean Motion  Mean Motion (revolutions per day)  \
# count                    730.000000                         730.000000
# mean                       0.000159                          15.499768
# std                        0.000504                           0.005153
# min                       -0.010423                          15.486151
# 25%                        0.000145                          15.496107
# 50%                        0.000189                          15.499482
# 75%                        0.000243                          15.502592
# max                        0.001879                          15.517621
#
#        Eccentricity  diff_revs_number  Inclination (degrees)  \
# count    730.000000        730.000000             730.000000
# mean       0.000538         15.519635              51.640446
# std        0.000267          1.793801               0.001784
# min        0.000020          9.166667              51.633380
# 25%        0.000375         14.574405              51.639300
# 50%        0.000541         15.500000              51.640365
# 75%        0.000693         16.375000              51.641542
# max        0.001144         38.000000              51.647500
#
#        Right Ascension of the Ascending Node (degrees)  \
# count                                       730.000000
# mean                                        179.070174
# std                                         102.513997
# min                                           1.587012
# 25%                                          89.652022
# 50%                                         179.034219
# 75%                                         267.469170
# max                                         357.146988
#
#        Argument of Perigee (degrees)  Mean Anomaly (degrees)
# count                     730.000000              730.000000
# mean                      163.336653              167.814147
# std                       114.259964               60.243615
# min                         1.296960               26.820175
# 25%                        63.904381              122.072554
# 50%                       136.506968              162.895584
# 75%                       279.156096              212.180574
# max                       358.370380              348.229450

# %%
from statsmodels.tsa.stattools import adfuller, kpss

# ADF : unit root test ==> null hypothesis is non-stationary
# Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test ==> null hypothesis is stationary

print('At confidence level 90%')

for col in data.columns:
    col_series = data[col]
    
    print(f"Features : {col}")
    # Perform the ADF test
    adf_result = adfuller(col_series)
    #     print("ADF Statistic:", adf_result[0])
    #     print("p-value:", adf_result[1])
    #     print("Critical Values:", adf_result[4])
    
    if adf_result[1] < 0.1:
        print(f'p-value: {adf_result[1]} , Reject null for ADF: Stationary')
    else:
        print(f'p-value: {adf_result[1]} , Accept null for ADF: Non-stationary')
        
    # Perform the KPSS test
    #     kpss_result = kpss(col_series)

    #     if kpss_result[1] < 0.05:
    #         print('Reject null for KPSS: Non-stationary')
    #     else:
    #         print('Accept null for KPSS: Stationary')
    
    print('=='*30)
# Out:
# At confidence level 90%
# Features : First Derivative Mean Motion
# p-value: 0.0 , Reject null for ADF: Stationary
# ============================================================
# Features : Mean Motion (revolutions per day)
# p-value: 3.2442485780624994e-05 , Reject null for ADF: Stationary
# ============================================================
# Features : Eccentricity
# p-value: 0.07745044776427039 , Reject null for ADF: Stationary
# ============================================================
# Features : diff_revs_number
# p-value: 1.3725886932812817e-27 , Reject null for ADF: Stationary
# ============================================================
# Features : Inclination (degrees)
# p-value: 0.0009958040313833088 , Reject null for ADF: Stationary
# ============================================================
# Features : Right Ascension of the Ascending Node (degrees)
# p-value: 6.855453593013844e-07 , Reject null for ADF: Stationary
# ============================================================
# Features : Argument of Perigee (degrees)
# p-value: 1.2313767313748493e-05 , Reject null for ADF: Stationary
# ============================================================
# Features : Mean Anomaly (degrees)
# p-value: 5.9749052204440715e-06 , Reject null for ADF: Stationary
# ============================================================

# %%
plt.plot(data['Mean Anomaly (degrees)'])

# %%
# --- 2. Data Preparation for Multi-Output Forecasting ---
# We will create a dataset where the model predicts the next 1 time steps
# using the previous 10 time steps.
look_back = 2 # current + 2 records
forecast_horizon = 1
features = []
targets = []
num_samples = data_for_training.shape[0]

# %%
for i in range(num_samples - look_back - forecast_horizon + 1):
    # The input features are the last `look_back` values of all series
    X_window = data.iloc[i : i + look_back].values
    
    # The target variables are the next `forecast_horizon` values of all series
    y_window = data.iloc[i + look_back : i + look_back + forecast_horizon].values
    
    # Flatten the windows to create a single row for the features and targets
    features.append(X_window.flatten())
    targets.append(y_window.flatten())

X = np.array(features)
y = np.array(targets)

print(f"Shape of X (input features): {X.shape}")
print(f"Shape of y (target variables): {y.shape}")
# Out:
# Shape of X (input features): (728, 16)
# Shape of y (target variables): (728, 8)

# %%
# --- 3. Scaling the Data ---
# It's good practice to scale the data, especially for models that are
# sensitive to feature magnitudes. We use a MinMaxScaler.
# We need to scale X and y separately, and use a different scaler for each
# to allow for inverse transformation later.

# X_scaler = MinMaxScaler()
# y_scaler = MinMaxScaler()

X_scaler = StandardScaler()
y_scaler = StandardScaler()

X_scaled = X_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y)

# --- 4. Splitting the Data ---
# For time series, we split chronologically. The last 20% of the data
# will be used for testing.
split_index = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
y_train, y_test = y_scaled[:split_index], y_scaled[split_index:]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((582, 16), (582, 8), (146, 16), (146, 8))

# %%
# --- 5. Model Training ---
# We instantiate a base estimator (RandomForestRegressor) and then wrap it
# with the MultiOutputRegressor. This allows the model to predict all
# output variables simultaneously.
base_estimator = RandomForestRegressor(n_estimators=100, random_state=42)
model = MultiOutputRegressor(base_estimator, n_jobs=-1)

# Train the model on the scaled training data
print("\nTraining the model...")
model.fit(X_train, y_train)
print("Model training complete.")
# Out:
# Training the model...
# Model training complete.

# %%
# Save model
import joblib
import os

# --- 6. Save the Trained Model ---
# We'll save the model and the scalers so we can use them later without
# retraining.
model_filename = 'multi_output_model.joblib'
x_scaler_filename = 'x_scaler.joblib'
y_scaler_filename = 'y_scaler.joblib'

save_path = 'MultiOutputModel'


joblib.dump(model, os.path.join(save_path,model_filename))
joblib.dump(X_scaler, os.path.join(save_path,x_scaler_filename))
joblib.dump(y_scaler, os.path.join(save_path,y_scaler_filename))
print(f"\nModel and scalers saved to {model_filename}, {x_scaler_filename}, and {y_scaler_filename}")
# Out:
# Model and scalers saved to multi_output_model.joblib, x_scaler.joblib, and y_scaler.joblib

# %%
# --- 6. Prediction and Inverse Scaling ---
# Make predictions on the test set. The predictions will be scaled.
y_pred_scaled = model.predict(X_test)

# Inverse transform the predictions and the actual test data to their original scale
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_test_original = y_scaler.inverse_transform(y_test)

# %%
# --- 7. Evaluation and Visualization ---
# Reshape the data back into its original time series format for plotting and evaluation.
# The shape is (num_test_samples, forecast_horizon * num_series).
# We want to reshape it to (num_test_samples, forecast_horizon, num_series).
y_test_reshaped = y_test_original.reshape(y_test_original.shape[0], forecast_horizon, -1)
y_pred_reshaped = y_pred_original.reshape(y_pred_original.shape[0], forecast_horizon, -1)

# %%
from sklearn.metrics import mean_squared_error

# %%
# Calculate MAE and MAPE for each series over the entire test set
mae_per_series = []
mape_per_series = []
rmse_per_series = []
for i in range(y_test_reshaped.shape[2]):
    actual_series = y_test_reshaped[:, :, i]
    pred_series = y_pred_reshaped[:, :, i]
    
    # Calculate MAE
    mae = mean_absolute_error(actual_series, pred_series)
    mse = mean_squared_error(actual_series, pred_series)
    rmse = np.sqrt(mse)
    rmse_per_series.append(rmse)
    mae_per_series.append(mae)
    
    # Calculate a simple version of MAPE (Mean Absolute Percentage Error)
    # We use a small epsilon to avoid division by zero.
    # Note: MAPE is sensitive to zero or near-zero values.
    non_zero_actuals = actual_series[np.abs(actual_series) > 1e-6]
    if len(non_zero_actuals) > 0:
        percentage_error = np.mean(np.abs((pred_series[np.abs(actual_series) > 1e-6] - non_zero_actuals) / non_zero_actuals)) * 100
    else:
        percentage_error = np.nan
    mape_per_series.append(percentage_error)

print("\nMean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) for each time series:")
for i in range(len(mae_per_series)):
#     print(f"  - Series {i+1} ({cols_for_training[i]}): MAE = {mae_per_series[i]:.4f}, MAPE = {mape_per_series[i]:.2f}%")
#     print(f"  - Series {i+1} ({cols_for_training[i]}): MAE = {mae_per_series[i]:.4f}")
    print(f"  - Series {i+1} ({cols_for_training[i]}): RMSE = {rmse_per_series[i]:.4f} :MAE = {mae_per_series[i]:.9f}, MAPE = {mape_per_series[i]:.2f}%")
# Out:
# Mean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) for each time series:
#   - Series 1 (First Derivative Mean Motion): RMSE = 0.0010 :MAE = 0.000270331, MAPE = 138.91%
#   - Series 2 (Mean Motion (revolutions per day)): RMSE = 0.0024 :MAE = 0.001418423, MAPE = 0.01%
#   - Series 3 (Eccentricity): RMSE = 0.0001 :MAE = 0.000046663, MAPE = 6.08%
#   - Series 4 (diff_revs_number): RMSE = 1.3918 :MAE = 1.068231339, MAPE = 7.14%
#   - Series 5 (Inclination (degrees)): RMSE = 0.0010 :MAE = 0.000689858, MAPE = 0.00%
#   - Series 6 (Right Ascension of the Ascending Node (degrees)): RMSE = 18.0638 :MAE = 6.056949248, MAPE = 59.52%
#   - Series 7 (Argument of Perigee (degrees)): RMSE = 35.9280 :MAE = 16.108020723, MAPE = 167.01%
#   - Series 8 (Mean Anomaly (degrees)): RMSE = 47.7140 :MAE = 35.339493555, MAPE = 20.77%

# %%
y_test_reshaped.shape
# Out:
# (146, 1, 8)

# %%
# Plot the predictions vs. actual values for the first time series

for i in range(len(cols_for_training)):
    plt.figure(figsize=(15, 6))
    plt.title(f"Figure {i} {cols_for_training[i]}: Actual vs. Predicted (Test Set)")
    
    if cols_for_training[i] == 'diff_revs_number':
        plt.plot(y_test_reshaped[:, 0, i].cumsum(), label='Actual', color='blue')
        plt.plot(y_pred_reshaped[:, 0, i].cumsum(), label='Predicted', color='red', linestyle='--')

    else:
        plt.plot(y_test_reshaped[:, 0, i], label='Actual', color='blue')
        plt.plot(y_pred_reshaped[:, 0, i], label='Predicted', color='red', linestyle='--')
        
#     plt.plot(y_test_reshaped[:, 0, i], label='Actual', color='blue')
#     plt.plot(y_pred_reshaped[:, 0, i], label='Predicted', color='red', linestyle='--')
    plt.legend()
    plt.grid(True)
    plt.xlabel("Test Sample")
    plt.ylabel(f"{cols_for_training[i]} Value")
    plt.show()

# %%
# # Plot the predictions for the first few test samples
# plt.figure(figsize=(15, 6))
# for i in range(3):
#     start_index = i * forecast_horizon
#     end_index = start_index + forecast_horizon
    
#     # Plotting the actual future values
#     actual_future = y_test_reshaped[i, :, 0]
#     plt.plot(range(start_index, end_index), actual_future, label=f'Actual Sample {i+1}', color=f'C{i}')
    
#     # Plotting the predicted future values
#     predicted_future = y_pred_reshaped[i, :, 0]
#     plt.plot(range(start_index, end_index), predicted_future, label=f'Predicted Sample {i+1}', linestyle='--', color=f'C{i}')

#     plt.legend()
#     plt.grid(True)
#     plt.title(f"Detailed Forecast for First 3 Test Samples (Time Series 1)")
    
#     plt.xlabel("Time Step (Relative)")
#     plt.ylabel("Value")
#     plt.show()

# %% [markdown]
# # Hyperparams. tuning

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# --- 5. Model Training and Hyperparameter Tuning ---
# We will now use GridSearchCV to find the best hyperparameters for multiple models.
# The best model will be selected for evaluation.

models = {
    'RandomForestRegressor': {
        'estimator': RandomForestRegressor(random_state=42),
        'param_grid': {'estimator__n_estimators': [50, 100, 200], 'estimator__max_depth': [None, 5, 10]}
    },
    'KNeighborsRegressor': {
        'estimator': KNeighborsRegressor(),
        'param_grid': {'estimator__n_neighbors': [3, 5, 7], 'estimator__weights': ['uniform', 'distance']}
    },
    'GradientBoostingRegressor': {
        'estimator': GradientBoostingRegressor(random_state=42),
        'param_grid': {'estimator__n_estimators': [50, 100], 'estimator__learning_rate': [0.05, 0.1]}
    },
    # SVR can be very slow, so we use a small, simple grid.
    'SVR': {
        'estimator': SVR(),
        'param_grid': {'estimator__kernel': ['rbf'], 'estimator__C': [0.1, 1, 10]}
    }
}

best_model = None
best_score = -np.inf
best_model_name = ""

print("\nStarting Hyperparameter Tuning...")

for name, model_data in models.items():
    print(f"\n--- Tuning {name} ---")
    base_estimator = model_data['estimator']
    param_grid = model_data['param_grid']
    
    # Wrap the base estimator in MultiOutputRegressor
    multi_output_estimator = MultiOutputRegressor(base_estimator, n_jobs=-1)
    
    # Set up GridSearchCV
    grid_search = GridSearchCV(multi_output_estimator, param_grid, cv=3, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=1)
    
    # Fit the grid search on the training data
    grid_search.fit(X_train, y_train)
    
    print(f"Finished tuning {name}")
    print(f"Best parameters for {name}: {grid_search.best_params_}")
    print(f"Best cross-validation score (negative MAE) for {name}: {grid_search.best_score_:.4f}")
    
    # Check if this is the best model so far
    if grid_search.best_score_ > best_score:
        best_score = grid_search.best_score_
        best_model = grid_search.best_estimator_
        best_model_name = name

print(f"\nModel tuning complete. The overall best model is: {best_model_name}")
# Out:
# Starting Hyperparameter Tuning...
#
# --- Tuning RandomForestRegressor ---
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# Finished tuning RandomForestRegressor
# Best parameters for RandomForestRegressor: {'estimator__max_depth': 5, 'estimator__n_estimators': 50}
# Best cross-validation score (negative MAE) for RandomForestRegressor: -0.3387
#
# --- Tuning KNeighborsRegressor ---
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Finished tuning KNeighborsRegressor
# Best parameters for KNeighborsRegressor: {'estimator__n_neighbors': 7, 'estimator__weights': 'distance'}
# Best cross-validation score (negative MAE) for KNeighborsRegressor: -0.5203
#
# --- Tuning GradientBoostingRegressor ---
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Finished tuning GradientBoostingRegressor
# Best parameters for GradientBoostingRegressor: {'estimator__learning_rate': 0.05, 'estimator__n_estimators': 100}
# Best cross-validation score (negative MAE) for GradientBoostingRegressor: -0.3712
#
# --- Tuning SVR ---
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# Finished tuning SVR
# Best parameters for SVR: {'estimator__C': 1, 'estimator__kernel': 'rbf'}
# Best cross-validation score (negative MAE) for SVR: -0.4108
#
# Model tuning complete. The overall best model is: RandomForestRegressor

# %%
model_filename = 'best_multi_output_model.joblib'
save_path = 'MultiOutputModel'


joblib.dump(best_model, os.path.join(save_path,model_filename))
# Out:
# ['MultiOutputModel/best_multi_output_model.joblib']

# %%
# --- 6. Prediction and Inverse Scaling ---
# Make predictions on the test set. The predictions will be scaled.
y_pred_scaled = best_model.predict(X_test)

# Inverse transform the predictions and the actual test data to their original scale
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_test_original = y_scaler.inverse_transform(y_test)

# %%
y_test_reshaped = y_test_original.reshape(y_test_original.shape[0], forecast_horizon, -1)
y_pred_reshaped = y_pred_original.reshape(y_pred_original.shape[0], forecast_horizon, -1)




# Calculate MAE and MAPE for each series over the entire test set
mae_per_series = []
mape_per_series = []
for i in range(y_test_reshaped.shape[2]):
    actual_series = y_test_reshaped[:, :, i]
    pred_series = y_pred_reshaped[:, :, i]
    
    # Calculate MAE
    mae = mean_absolute_error(actual_series, pred_series)
    mae_per_series.append(mae)
    
    # Calculate a simple version of MAPE (Mean Absolute Percentage Error)
    # We use a small epsilon to avoid division by zero.
    # Note: MAPE is sensitive to zero or near-zero values.
    non_zero_actuals = actual_series[np.abs(actual_series) > 1e-6]
    if len(non_zero_actuals) > 0:
        percentage_error = np.mean(np.abs((pred_series[np.abs(actual_series) > 1e-6] - non_zero_actuals) / non_zero_actuals)) * 100
    else:
        percentage_error = np.nan
    mape_per_series.append(percentage_error)

print("\nMean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) for each time series:")
for i in range(len(mae_per_series)):
#     print(f"  - Series {i+1} ({cols_for_training[i]}): MAE = {mae_per_series[i]:.4f}, MAPE = {mape_per_series[i]:.2f}%")
    print(f"  - Series {i+1} ({cols_for_training[i]}): MAE = {mae_per_series[i]:.4f}")
# Out:
# Mean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) for each time series:
#   - Series 1 (First Derivative Mean Motion): MAE = 0.0003
#   - Series 2 (Mean Motion (revolutions per day)): MAE = 0.0014
#   - Series 3 (Eccentricity): MAE = 0.0000
#   - Series 4 (diff_revs_number): MAE = 1.0682
#   - Series 5 (Inclination (degrees)): MAE = 0.0007
#   - Series 6 (Right Ascension of the Ascending Node (degrees)): MAE = 6.0569
#   - Series 7 (Argument of Perigee (degrees)): MAE = 16.1080
#   - Series 8 (Mean Anomaly (degrees)): MAE = 35.3395
